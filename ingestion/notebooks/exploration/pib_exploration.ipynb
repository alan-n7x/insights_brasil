# %%
import os

os.sys.path.append(r"E:\Developer\insights_brasil")

from ingestion.ibge.services.municipio_sync_service import MunicipiosService
from ingestion.ibge.transformers.municipio_transformer import MunicipioTransformer
from ingestion.ibge.clients.ibge_client import IBGEClient



from ingestion.ibge.clients.ibge_client import IBGEClient
from ingestion.ibge.clients.sidra_client import IBGESidraClient



pib = IBGESidraClient(IBGEClient())

dados = pib.get_pib(2018, 2021)

print(type(dados))

print(len(dados))

print(dados[0].keys())

print(dados[0]["resultados"][0].keys())

print(dados[0]["resultados"][0])
# Out:
# <class 'list'>
# 1
# dict_keys(['id', 'variavel', 'unidade', 'resultados'])
# dict_keys(['classificacoes', 'series'])
# {'classificacoes': [], 'series': [{'localidade': {'id': '1100015', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': "Alta Floresta D'Oeste - RO"}, 'serie': {'2018': '498980', '2019': '495775', '2020': '570242', '2021': '734467'}}, {'localidade': {'id': '1100023', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Ariquemes - RO'}, 'serie': {'2018': '2464704', '2019': '2579278', '2020': '2817331', '2021': '3211294'}}, {'localidade': {'id': '1100031', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Cabixi - RO'}, 'serie': {'2018': '140503', '2019': '139976', '2020': '167153', '2021': '238414'}}, {'localidade': {'id': '1100049', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Cacoal - RO'}, 'serie': {'2018': '2175840', '2019': '2261930', '2020': '2518845', '2021': '2792506'}}, {'localidade': {'id': '1100056', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Cerejeiras - RO'}, 'serie': {'2018': '470647', '2019': '506494', '2020': '600630', '2021': '743062'}}, {'localidade': {'id': '1100064', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Colorado do Oeste - RO'}, 'serie': {'2018': '330232', '2019': '334922', '2020': '366922', '2021': '424846'}}, {'localidade': {'id': '1100072', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Corumbiara - RO'}, 'serie': {'2018': '320416', '2019': '349289', '2020': '268353', '2021': '396740'}}, {'localidade': {'id': '1100080', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Costa Marques - RO'}, 'serie': {'2018': '230151', '2019': '238796', '2020': '261944', '2021': '316672'}}, {'localidade': {'id': '1100098', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': "Espigão D'Oeste - RO"}, 'serie': {'2018': '606072', '2019': '624787', '2020': '666321', '2021': '773372'}}, {'localidade': {'id': '1100106', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Guajará-Mirim - RO'}, 'serie': {'2018': '837459', '2019': '892778', '2020': '984614', '2021': '1054255'}}, {'localidade': {'id': '1100114', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Jaru - RO'}, 'serie': {'2018': '1484555', '2019': '1500855', '2020': '1665151', '2021': '1764718'}}, {'localidade': {'id': '1100122', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Ji-Paraná - RO'}, 'serie': {'2018': '3466810', '2019': '3783206', '2020': '4057176', '2021': '4230355'}}, {'localidade': {'id': '1100130', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': "Machadinho D'Oeste - RO"}, 'serie': {'2018': '642283', '2019': '632997', '2020': '700188', '2021': '890319'}}, {'localidade': {'id': '1100148', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': "Nova Brasilândia D'Oeste - RO"}, 'serie': {'2018': '345779', '2019': '359625', '2020': '403373', '2021': '549853'}}, {'localidade': {'id': '1100155', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Ouro Preto do Oeste - RO'}, 'serie': {'2018': '807497', '2019': '834959', '2020': '885132', '2021': '986046'}}, {'localidade': {'id': '1100189', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Pimenta Bueno - RO'}, 'serie': {'2018': '1129770', '2019': '1164694', '2020': '1361160', '2021': '1642621'}}, {'localidade': {'id': '1100205', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Porto Velho - RO'}, 'serie': {'2018': '16655670', '2019': '17906443', '2020': '19446740', '2021': '20056138'}}, {'localidade': {'id': '1100254', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Presidente Médici - RO'}, 'serie': {'2018': '418683', '2019': '427885', '2020': '464090', '2021': '560210'}}, {'localidade': {'id': '1100262', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Rio Crespo - RO'}, 'serie': {'2018': '102476', '2019': '111100', '2020': '133557', '2021': '184428'}}, {'localidade': {'id': '1100288', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': 'Rolim de Moura - RO'}, 'serie': {'2018': '1291476', '2019': '1281314', '2020': '1403499', '2021': '1565241'}}, {'localidade': {'id': '1100296', 'nivel': {'id': 'N6', 'nome': 'Município'}, 'nome': "Santa Lu ...
