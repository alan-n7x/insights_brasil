# %%
# 01_exploracao_pib.ipynb – célula 1 (setup)
import sys
from pathlib import Path

# ---- Adiciona a raiz do projeto ao PATH ----
PROJECT_ROOT = Path(__file__).resolve().parents[2]   # insights_brasil
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# ---- Configura o Django ----
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "core.settings")
import django
django.setup()

# ---- Opcional: autoreload durante desenvolvimento ----
# %load_ext autoreload
# %autoreload 2


from ibge.models import FatoIndicador

# consulta base
qs = FatoIndicador.objects.filter(indicador="PIB")
qs.values("municipio_id", "ano", "valor")[:10]
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# Cell In[2], line 5
#       1 import os
#       2 import django
#       3
#       4
# ----> 5 from models.sidra_indicadores import FatoIndicador
#       6
#       7 # consulta base
#       8 qs = FatoIndicador.objects.filter(indicador="PIB")
#
# File e:\Developer\insights_brasil\ibge\models\__init__.py:1
# ----> 1 from .territorio import *
#       2 from .sidra_indicadores import *
#
# File e:\Developer\insights_brasil\ibge\models\territorio.py:7
#       1 from django.db import models
#       4 # =========================
#       5 # DIMENSÃO: TEMPO
#       6 # =========================
# ----> 7 class Tempo(models.Model):
#       8     """
#       9     Dimensão temporal para suportar diferentes granularidades.
#      10     Permite dados anuais, mensais, trimestrais, semestrais.
#      11     """
# ...
